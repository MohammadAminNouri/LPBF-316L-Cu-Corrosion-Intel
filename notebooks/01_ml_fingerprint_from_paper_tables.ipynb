# %% [markdown]
# # ML-assisted electrochemical fingerprinting
# This notebook reproduces the figures from the manuscript-derived feature table.

# %%
import pandas as pd
from src.feature_engineering import add_corrosion_severity_index
from src.ml_fingerprint import pca_fingerprint
df = pd.read_csv('../data/processed/paper_extracted_corrosion_features.csv')
df = add_corrosion_severity_index(df)
df
